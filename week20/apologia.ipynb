# %%
import pandas as pd

# %% [markdown]
# # Goals and Motivations
# A central criticism was that this project was too unfocused, and was plagued by repeated tangents without meaningful progress towards anything. I do understand the motivations behind this, but would like to defend myself on specifically this front.
# Firstly, I would like to show that every iteration of my research questions, or redefinition of scope was in line with the same overall goal, and was merely a result of better defining the question. Here is a line from the original one-page proposal:
# "A useful insight towards this comes from [2], which states that a central characteristic of a frame is that it contains ambivalence. This insight forms the foundation for the proposed work". In the slides on 12-09 meeting, I quoted another paper, saying "Few studies attempt to reevaluate detected topics in terms of their “frame-ness”", indicating my desire to address this gap. In the meeting on Jan 28, I have in my notes that "movement away from topic modeling towards identifying ambivalence is acceptable not just as a choice but as a defined research direction".
# Precisely identifying this idea of ambivalence, however, was not as easy. In the original one-page, I assumed that we would identify ambivalence as the amount of difficulty that it would take to re-write one news article to one with a viewpoint that was opposing it. This method quickly proved to be untenable, as is discussed in the Method section. In February/March, I attempted to find a dataset that was labeled on two or more frames, to not much avail. In April, I asked to change the research questions away from anything involving controlled generation or "re-writing" because of these difficulties. As I highlight in the Method section, this was not due to a whim or becoming disillusioned with controlled generation - there was simply no testable hypothesis that I could think of. Perhaps I should have been clearer about these motivations, but I did bring this change to the meeting, and it was agreed on.
# However, there is a strong argument that this change was to one that was more aligned with the original proposal. In the original slides,
